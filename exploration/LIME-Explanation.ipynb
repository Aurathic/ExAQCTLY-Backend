# %% [markdown]
# # Using Lime with Pytorch

# %% [markdown]
# In this tutorial we will show how to use Lime framework with Pytorch. Specifically, we will use Lime to explain the prediction generated by one of the pretrained ImageNet models.
#
# Let's start with importing our dependencies. This code is tested with Pytorch 1.0 but should work with older versions as well.

# %%
pip install torch torchvision lime --user
# Out:
# Requirement already satisfied: torch in c:\python310\lib\site-packages (2.0.0)
# Requirement already satisfied: torchvision in c:\python310\lib\site-packages (0.15.1)
# Requirement already satisfied: lime in c:\users\ithin\appdata\roaming\python\python310\site-packages (0.2.0.1)
# Requirement already satisfied: filelock in c:\python310\lib\site-packages (from torch) (3.6.0)
# Requirement already satisfied: sympy in c:\python310\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: typing-extensions in c:\python310\lib\site-packages (from torch) (4.1.1)
# Requirement already satisfied: networkx in c:\users\ithin\appdata\roaming\python\python310\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\python310\lib\site-packages (from torch) (3.0.3)
# Requirement already satisfied: numpy in c:\users\ithin\appdata\roaming\python\python310\site-packages (from torchvision) (1.24.2)
# Requirement already satisfied: requests in c:\python310\lib\site-packages (from torchvision) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\python310\lib\site-packages (from torchvision) (9.0.1)
# Requirement already satisfied: scikit-image>=0.12 in c:\users\ithin\appdata\roaming\python\python310\site-packages (from lime) (0.20.0)
# Requirement already satisfied: scikit-learn>=0.18 in c:\python310\lib\site-packages (from lime) (1.0.2)
# Requirement already satisfied: scipy in c:\python310\lib\site-packages (from lime) (1.8.0)
# Requirement already satisfied: matplotlib in c:\users\ithin\appdata\roaming\python\python310\site-packages (from lime) (3.7.0)
# Requirement already satisfied: tqdm in c:\python310\lib\site-packages (from lime) (4.63.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\ithin\appdata\roaming\python\python310\site-packages (from scikit-image>=0.12->lime) (2.27.0)
# Requirement already satisfied: packaging>=20.0 in c:\python310\lib\site-packages (from scikit-image>=0.12->lime) (21.3)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\python310\lib\site-packages (from scikit-image>=0.12->lime) (2023.3.21)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\ithin\appdata\roaming\python\python310\site-packages (from scikit-image>=0.12->lime) (1.4.1)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\ithin\appdata\roaming\python\python310\site-packages (from scikit-image>=0.12->lime) (0.2)
# Requirement already satisfied: joblib>=0.11 in c:\python310\lib\site-packages (from scikit-learn>=0.18->lime) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python310\lib\site-packages (from scikit-learn>=0.18->lime) (3.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python310\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python310\lib\site-packages (from matplotlib->lime) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib->lime) (4.29.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib->lime) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\python310\lib\site-packages (from matplotlib->lime) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python310\lib\site-packages (from matplotlib->lime) (1.3.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python310\lib\site-packages (from matplotlib->lime) (3.0.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\python310\lib\site-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python310\lib\site-packages (from requests->torchvision) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python310\lib\site-packages (from requests->torchvision) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\python310\lib\site-packages (from requests->torchvision) (3.3)
# Requirement already satisfied: mpmath>=0.19 in c:\python310\lib\site-packages (from sympy->torch) (1.2.1)
# Requirement already satisfied: colorama in c:\python310\lib\site-packages (from tqdm->lime) (0.4.4)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->lime) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy --upgrade --ignore-installed --user
# Out:
# Collecting numpy
#   Using cached numpy-1.24.2-cp310-cp310-win_amd64.whl (14.8 MB)
# Installing collected packages: numpy
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\ithin\\AppData\\Roaming\\Python\\Python310\\site-packages\\numpy\\.libs\\libopenblas64__v0.3.21-gcc_10_3_0.dll'
# Check the permissions.

# %%
import matplotlib.pyplot as plt
from PIL import Image
import torch.nn as nn
import numpy as np
import os, json

import torch
from torchvision import models, transforms
from torch.autograd import Variable
import torch.nn.functional as F

# %% [markdown]
# Load our test image and see how it looks.

# %%
def get_image(path):
    with open(os.path.abspath(path), 'rb') as f:
        with Image.open(f) as img:
            return img.convert('RGB') 
        
img = get_image('./data/dogs.png')
plt.imshow(img)

# %% [markdown]
# We need to convert this image to Pytorch tensor and also apply whitening as used by our pretrained model.

# %%
# resize and take the center part of image to what our model expects
def get_input_transform():
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                    std=[0.229, 0.224, 0.225])       
    transf = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        normalize
    ])    

    return transf

def get_input_tensors(img):
    transf = get_input_transform()
    # unsqeeze converts single image to batch of 1
    return transf(img).unsqueeze(0)

# %% [markdown]
# Load the pretrained model for Resnet50 available in Pytorch.

# %%
model = models.inception_v3(pretrained=True)
# Out:
# C:\Python310\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# Load label texts for ImageNet predictions so we know what model is predicting

# %%
idx2label, cls2label, cls2idx = [], {}, {}
with open(os.path.abspath('./data/imagenet_class_index.json'), 'r') as read_file:
    class_idx = json.load(read_file)
    idx2label = [class_idx[str(k)][1] for k in range(len(class_idx))]
    cls2label = {class_idx[str(k)][0]: class_idx[str(k)][1] for k in range(len(class_idx))}
    cls2idx = {class_idx[str(k)][0]: k for k in range(len(class_idx))}

# %% [markdown]
# Get the predicition for our image.

# %%
img_t = get_input_tensors(img)
model.eval()
logits = model(img_t)

# %% [markdown]
# Predicitions we got are logits. Let's pass that through softmax to get probabilities and class labels for top 5 predictions.

# %%
probs = F.softmax(logits, dim=1)
probs5 = probs.topk(5)
tuple((p,c, idx2label[c]) for p, c in zip(probs5[0][0].detach().numpy(), probs5[1][0].detach().numpy()))
# Out:
# ((0.93593, 239, 'Bernese_mountain_dog'),
#  (0.038447928, 241, 'EntleBucher'),
#  (0.023756307, 240, 'Appenzeller'),
#  (0.0018181851, 238, 'Greater_Swiss_Mountain_dog'),
#  (9.113272e-06, 214, 'Gordon_setter'))

# %% [markdown]
# We are getting ready to use Lime. Lime produces the array of images from original input image by pertubation algorithm. So we need to provide two things: (1) original image as numpy array (2) classification function that would take array of purturbed images as input and produce the probabilities for each class for each image as output.
#
# For Pytorch, first we need to define two separate transforms: (1) to take PIL image, resize and crop it (2) take resized, cropped image and apply whitening.

# %%
def get_pil_transform(): 
    transf = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.CenterCrop(224)
    ])    

    return transf

def get_preprocess_transform():
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                    std=[0.229, 0.224, 0.225])     
    transf = transforms.Compose([
        transforms.ToTensor(),
        normalize
    ])    

    return transf    

pill_transf = get_pil_transform()
preprocess_transform = get_preprocess_transform()

# %% [markdown]
# Now we are ready to define classification function that Lime needs. The input to this function is numpy array of images where each image is ndarray of shape (channel, height, width). The output is numpy aaray of shape (image index, classes) where each value in array should be probability for that image, class combination.

# %%
def batch_predict(images):
    model.eval()
    batch = torch.stack(tuple(preprocess_transform(i) for i in images), dim=0)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    batch = batch.to(device)
    
    logits = model(batch)
    probs = F.softmax(logits, dim=1)
    return probs.detach().cpu().numpy()

# %% [markdown]
# Let's test our function for the sample image.

# %%
test_pred = batch_predict([pill_transf(img)])
test_pred.squeeze().argmax()
# Out:
# 239

# %% [markdown]
# Import lime and create explanation for this prediciton.

# %%
from lime import lime_image

# %%
explainer = lime_image.LimeImageExplainer()
explanation = explainer.explain_instance(np.array(pill_transf(img)), 
                                         batch_predict, # classification function
                                         top_labels=5, 
                                         hide_color=0, 
                                         num_samples=1000) # number of images that will be sent to classification function
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# Let's use mask on image and see the areas that are encouraging the top prediction.

# %%
from skimage.segmentation import mark_boundaries

# %%
explanation

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=5, hide_rest=False)
img_boundry1 = mark_boundaries(temp/255.0, mask)
plt.imshow(img_boundry1)

# %% [markdown]
# Let's turn on areas that contributes against the top prediction.

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=10, hide_rest=False)
img_boundry2 = mark_boundaries(temp/255.0, mask)
plt.imshow(img_boundry2)
